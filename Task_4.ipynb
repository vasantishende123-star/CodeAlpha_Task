# %% [markdown]
# <a href="https://colab.research.google.com/github/vasantishende123-star/CodeAlpha_Task/blob/main/Task_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# In Google Colab
# !pip install textblob

import pandas as pd
from textblob import TextBlob

# Example reviews (you can scrape more or use your own)
data = {
    'Review': [
        "This product is amazing! I love it.",
        "Worst phone ever. Total waste of money.",
        "It's okay, nothing special.",
        "Best purchase I made this year ❤️"
    ]
}
df = pd.DataFrame(data)

# Analyze sentiment
def get_sentiment(text):
    analysis = TextBlob(text)
    if analysis.sentiment.polarity > 0:
        return 'Positive'
    elif analysis.sentiment.polarity < 0:
        return 'Negative'
    else:
        return 'Neutral'

df['Sentiment'] = df['Review'].apply(get_sentiment)
df['Polarity'] = df['Review'].apply(lambda x: TextBlob(x).sentiment.polarity)

print(df)

# Count plot
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(data=df, x='Sentiment')
plt.title("Sentiment Analysis of Reviews")
plt.show()
# Out:
# ...
#                                     Review Sentiment  Polarity
# 0      This product is amazing! I love it.  Positive  0.625000
# 1  Worst phone ever. Total waste of money.  Negative -0.400000
# 2              It's okay, nothing special.  Positive  0.428571
# 3        Best purchase I made this year ❤️  Positive  1.000000
